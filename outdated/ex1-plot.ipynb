# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./data.csv", delimiter=" ", )

# %%
data_c = data[data.ver == 'c']
data_r = data[data.ver == 'r']

# %%
plt.figure(dpi=200)
# plt.xscale("log")
plt.loglog()
# plt.plot(data_c.n, data_c.avg, c="tab:blue")
plt.errorbar(data_c.n, data_c.avg, yerr=data_c.upper-data_c.avg, fmt="-.")
plt.fill_between(data_c.n, data_c.avg-data_c.stddev, data_c.avg+data_c.stddev, alpha=.3)
plt.plot(data_c.n, data_c.med, c="tab:orange")
plt.plot(data_c.n, data_c["min"], c="tab:green")
